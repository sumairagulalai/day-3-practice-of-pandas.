# %%
import pandas as pd
csv = pd.read_csv("C:\\Users\\sumai\\OneDrive\\student5.csv")
print(csv)
# Out:
#      name  math  science       city
# 0     Ali  80.0     75.0   Peshawar
# 1    Sara  90.0      NaN  Islamabad
# 2   Ahmed  45.0     50.0     Lahore
# 3  Ayesha   NaN     88.0    Karachi
# 4   Bilal  70.0     65.0   Peshawar
# 5    Hina  95.0     92.0        NaN
# 6     Ali  80.0     75.0   Peshawar
# 7    Sara  90.0      NaN  Islamabad

# %%
# describe 
describ = csv["math"].describe()
print(describ)
# Out:
# count     7.000000
# mean     78.571429
# std      17.008401
# min      45.000000
# 25%      75.000000
# 50%      80.000000
# 75%      90.000000
# max      95.000000
# Name: math, dtype: float64

# %%
# math mean 
mathmean = csv["math"].mean()
print(mathmean)
# Out:
# 78.57142857142857

# %%
mathmin = csv["math"].min()
print(mathmin)
# Out:
# 45.0

# %%
mathmax = csv["math"].max()
print(mathmax)
# Out:
# 95.0

# %%
mathsum = csv["math"].sum()
print(mathsum)
# Out:
# 550.0

# %%
uniqu = csv["math"].unique()
print(uniqu)
# Out:
# [80. 90. 45. nan 70. 95.]

# %%
groupby = csv.groupby("city")["math"].mean()
print(groupby)
# Out:
# city
# Islamabad    90.000000
# Karachi            NaN
# Lahore       45.000000
# Peshawar     76.666667
# Name: math, dtype: float64

# %%
agge = csv["math"].agg(["min","max","mean","sum"])
print(agge)
# Out:
# min      45.000000
# max      95.000000
# mean     78.571429
# sum     550.000000
# Name: math, dtype: float64

# %%
corr = csv[["math","science"]].corr()
print(corr)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: ('math', 'science')
#
# The above exception was the direct cause of the following exception:
#
# ...
